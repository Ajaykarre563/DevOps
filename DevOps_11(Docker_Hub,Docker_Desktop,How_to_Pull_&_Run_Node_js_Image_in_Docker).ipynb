# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **what is mean by Docker Hub?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **what is mean by Docker Desktop?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Docker Desktop is an application that allows you to build, run, and manage Docker containers on your local machine (Windows, macOS, or Linux).**

# %% [markdown]
# # **How to Pull & Run Node.js Image in Docker**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
