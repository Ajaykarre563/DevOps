# %% [markdown]
# # **deploy a static website on GitHub Pages**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **How to Deploy Vite React App**

# %% [markdown]
# # ✅ **Step 2: Install GitHub Pages Deployment Package**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **✅ What is git diff?**
# git diff shows the differences between two versions of your code

# %% [markdown]
# # **for example, what has changed since your last commit.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **If we want to see with file is change**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
