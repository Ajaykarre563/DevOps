# %% [markdown]
# # **🔄 What is the Use of Fork in GitHub?**

# %% [markdown]
# **A fork is used to create your own copy of someone else’s repository for you — in your GitHub account.**
#
#
# ✅ You: It gives you full control over the copy.
#
# 🚫 Not for others: Others can fork your fork if they want, but your fork is mainly for your personal development and contribution.
#
# 📌 In Short:
#
# “A fork is your personal copy of someone else’s project on GitHub, which you can edit, update, and use to send pull requests.”

# %% [markdown]
# # **README.md**

# %% [markdown]
# # **📘 What is README.md?**
# README.md is a markdown file that gives basic information about a project on GitHub or any code repository.
#
# **✅ Main Uses:**
#
# 📄 Describes the project – what it does, why it exists, how to use it.
#
# ⚙️ Explains installation steps, usage instructions, and examples.
#
# 🙋‍♂️ Helps new users or developers understand the codebase quickly.
#
# **📌 Why .md?**
#
# .md stands for Markdown – a lightweight markup language used to style text (like bold, headers, links).

# %% [markdown]
# # **Example**

# %% [markdown]
# ```
# # My Project
# This is a simple web app.
#
# ## Features
# - Login
# - Sign up
#
# ## How to Run
# ```bash
# npm install
# npm start
#
# ```

# %% [markdown]
# # **🐱 What is GitHub?**
# GitHub is a web-based platform used for version control and collaboration. It allows developers to store, manage, and track changes to their code using Git.

# %% [markdown]
# # **what is mean by GitHub Actions?**

# %% [markdown]
# GitHub Actions is a CI/CD (Continuous Integration and Continuous Deployment) tool built into GitHub. It helps automate tasks like testing, building, and deploying your code directly from your GitHub repository.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔄 GitHub Actions Workflow**

# %% [markdown]
# A GitHub Actions Workflow is a set of automated instructions written in YAML that runs when triggered by an event (like code push or pull request).

# %% [markdown]
# ```
# 📂 Where is it saved?
# In your repository:
# 📁 .github/workflows/workflow-name.yml
#
# ```

# %% [markdown]
# # **GO to Action Then select New WorkFlow**

# %% [markdown]
# # **workflow-name.yml**

# %% [markdown]
# ```
# name: Ajay Karre
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   demo:
#     runs-on: ubuntu-latest
#
#     steps:
#       - name: Greetings
#         run: echo "Hello From Apun"
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
