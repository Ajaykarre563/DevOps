# %% [markdown]
# # **If you want to delete all images and container in docker desktop**

# %% [markdown]
# ```
#  deep clean your Docker environment
# ```

# %% [markdown]
# # **🧹 What It Removes:**
# ✅ All stopped containers
#
# ✅ All networks not used by at least one container
#
# ✅ All images not used by any container (including unused tagged images)
#
# ✅ All build cache

# %% [markdown]
# # **Build a Docker image from a Dockerfile located in the current directory.**

# %% [markdown]
# ```
# docker build -t node-app .
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Docker Volumes**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔁 What does nodemon do?**
# nodemon watches for file changes (like .js, .json, etc.) in your project. When it detects a change, it automatically restarts your Node.js server.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **How to Create & Use Volumes with Containers?**

# %% [markdown]
# # **dockerfile**

# %% [markdown]
# ```
# FROM node:latest
#
# RUN npm install -g nodemon
#
# WORKDIR /app
#
# COPY . .
#
# RUN npm install
#
# EXPOSE 4000
#
# CMD ["npm", "run", "dev"]
#
#
# ```

# %% [markdown]
# # **package.json** add it

# %% [markdown]
# ```
#  "dev": "nodemon --legacy-watch index.js"
# ```

# %% [markdown]
# # **index.js**

# %% [markdown]
# ```
# const express = require("express");
# const app = express();
#
# app.get("/", (req, res) => {
#   res.json([
#     {
#       id: 1,
#       employeeName: "Farzeen",
#       employeeSalary: 70000
#     },
#     {
#       id: 2,
#       employeeName: "Ajay",
#       employeeSalary: 65000
#     },
#     {
#       id: 3,
#       employeeName: "Neha",
#       employeeSalary: 80000
#     },
#     {
#       id: 4,
#       employeeName: "Rahul",
#       employeeSalary: 60000
#     },
#     {
#       id: 5,
#       employeeName: "Priya",
#       employeeSalary: 75000
#     }
#   ]);
# });
#
# app.listen(3000, () => {
#   console.log("Server is running on port 3000");
# });
#
# ```

# %% [markdown]
# # **command for Volume**

# %% [markdown]
# ```
# docker run --name my-container -p 3000:3000 --rm -v "C:/Users/karre/OneDrive/Desktop/Node App:/app" my-app
#
# ```

# %% [markdown]
# # **Note:**

# %% [markdown]
# # **🧠 Summary:**
#
# Volume = automatic sync of code/data between host and container.
#
# Best for development, not recommended for production unless necessary.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
