# %% [markdown]
# # **What is DevOps?**

# %% [markdown]
# **DevOps is a methodology that brings together Development (Dev) and Operations (Ops) teams to improve software delivery speed, quality, and reliability. It focuses on automation, collaboration, and continuous improvement.**

# %% [markdown]
# # **what is mean by Development(Creating Software 💻)**
#
# This part focuses on writing, testing, and improving software.
#
# Who? Developers, testers.
#
# What they do?
#
# ✅ Write & update code.
#
# ✅ Test features & fix bugs.
#
# ✅ Use version control (e.g., Git).
#
# 📌 Example: A developer writes code for a new payment feature in an e-commerce app.
#
# # **what is mean by Operations (Running & Maintaining Software ⚙️)**
#
# This part ensures that the software runs smoothly after deployment.
#
# Who? IT admins, system engineers.
#
# What they do?
#
# ✅ Deploy & manage applications.
#
# ✅ Monitor servers & fix issues.
#
# ✅ Ensure security & scalability.
#
# 📌 Example: The operations team ensures the payment system is live, secure, and fast, even during high traffic.

# %% [markdown]
# # **Why is DevOps Important?**
#
# Faster Releases – Automates processes to deploy software quickly.
#
# Better Quality – Continuous testing ensures fewer bugs.
#
# Improved Collaboration – Developers & IT teams work together.
#
# Scalability – Easily handle growing demands.
#
# **How is DevOps Used in Real Life?**
#
# Continuous Integration & Continuous Deployment (CI/CD)
#
# Automates code testing and deployment.
#
# Example: A banking app gets daily updates without downtime.
#
# Tools: Jenkins, GitLab CI/CD, Azure DevOps.
#
# **Cloud & Containerization**
#
# Deploys applications in scalable cloud environments.
#
# Example: Netflix uses AWS & Kubernetes to stream videos smoothly.
#
# Tools: AWS, Docker, Kubernetes.
#
# **Tracks app performance & prevents cyberattacks.**
#
# Example: E-commerce websites monitor traffic spikes to prevent crashes.
#
# Tools: Prometheus, Grafana, Splunk, SonarQube.
#
# **Real-Life Example**
#
# 🚀 E-commerce Website (e.g., Amazon, Flipkart)
#
# Developer pushes new features (e.g., faster checkout)

# %% [markdown]
# # **who should learn DevOps?**

# %% [markdown]
# 🚀 Software Developers → Automate deployments & CI/CD
#
# ⚙️ System Administrators → Manage infrastructure with code
#
# 🛠️ QA/Testers → Automate testing in pipelines
#
# 🌐 IT Support & Networking Engineers → Transition to cloud automation
#
# ☁️ Cloud Engineers → Work with AWS, Azure, Kubernetes
#
# 🎓 Freshers & Students → Learn high-demand skills
#
# 📊 Project Managers & IT Leaders → Improve software delivery efficiency

# %% [markdown]
# # **what is mean by Azure DevOps?**

# %% [markdown]
# **Azure DevOps is a set of tools and services by Microsoft that helps teams plan, develop, test, and deploy software efficiently. It combines development (Dev) and operations (Ops) to improve collaboration and automation in software projects.**

# %% [markdown]
# # **Example:**
#
# **Imagine a company developing a web application. Using Azure DevOps, the team can:**
#
# Plan Work – Use Azure Boards to track tasks, bugs, and progress.
#
# Develop Code – Store code in Azure Repos (a Git-based repository).
#
# Build & Test – Automate code builds and tests using Azure Pipelines.
#
# Deploy – Deploy the application to cloud servers with Azure Pipelines.
#
# Monitor & Improve – Use Azure Test Plans for testing and Azure Artifacts to
# manage dependencies.

# %% [markdown]
# # **Azure vs. Azure DevOps?**

# %% [markdown]
# ![Screenshot 2025-01-30 172927.png](data:image/png;base64,...)

# %% [markdown]
# ![dev.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Azure DevOps provides several services to help teams manage their software development lifecycle. Here's a simple explanation of each:**
#
# 1. **Azure Boards**
# Purpose: Helps teams plan, track, and discuss work items like tasks, bugs, and user stories.
#
# Example: A team uses Azure Boards to create and assign tasks for building new features in an app and track progress.
#
# 2. **Azure Repos**
# Purpose: A cloud-based repository for storing and managing code using Git.
#
# Example: Developers push and pull code to/from Azure Repos to work on the e-commerce website’s source code collaboratively.
#
# 3. **Azure Pipelines**
#
# Purpose: Automates the process of building, testing, and deploying code.
#
# Example: Whenever the development team pushes new code to Azure Repos, Azure Pipelines automatically runs tests and deploys the code to a test server.
#
# 4. **Azure Test Plans**
# Purpose: Helps teams manage and run manual tests for their application.
#
# Example: A tester uses Azure Test Plans to manually check if the checkout process on the e-commerce website works correctly after new updates.
#
# 5. **Azure Artifacts**
# Purpose: Manages and shares dependencies (like libraries or packages) used in the project.
#
# Example: A team uses Azure Artifacts to store and manage the software libraries that their web application depends on.
#
# **In Summary:**
#
# Azure Boards = Track and plan work.
#
# Azure Repos = Store and manage code.
#
# Azure Pipelines = Automate build, test, and deploy.
#
# Azure Test Plans = Manage manual testing.
#
# Azure Artifacts = Manage software dependencies.

# %% [markdown]
# ![Screenshot 2025-01-30 174734.png](data:image/png;base64,...)

# %% [markdown]
# # **To use your own server in Azure DevOps, you can set up a self-hosted agent. Here's how:**
#
# **Prepare Your Server:** Set up a server or virtual machine (on-premises or in the cloud) where you want to run your builds or deployments.
#
# **Install the Agent**: Download and install the Azure DevOps agent on your server.
#
# **Connect to Azure DevOps:** Link the agent to your Azure DevOps organization by following the setup instructions in the Azure DevOps portal.
