# %% [markdown]
# # **what is mean by  IAM User?**

# %% [markdown]
# **An IAM User in AWS (Amazon Web Services) stands for Identity and Access Management User. It is a specific identity created within your AWS account to allow a person or application to interact with AWS services securely.**

# %% [markdown]
# # **✅ Simple Definition:**
# IAM User = A named identity with specific permissions to access AWS resources.
#
# # **🧑‍💻 Example Use Case:**
# You have a team with 3 developers. You can create separate IAM users for:
#
# developer1
#
# developer2
#
# developer3
#
# # **Each user gets:**
#
# Their own login credentials
#
# Permissions (like access to EC2 or S3)
#
# Optional MFA (Multi-Factor Authentication)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Enter the access key & secret key**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **What is EC2 in AWS ?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **use cases**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **✅ Elastic IP (EIP) in AWS**(IP Address)
# An Elastic IP is a static public IPv4 address that you can assign to your EC2 instance.
#
# 🔹 Key Points:
# Unlike regular public IPs (which change when the instance stops/starts), an Elastic IP does not change.
#
# You can reassign it to different EC2 instances as needed.
#
# Useful for web servers, NAT gateways, or any service where a consistent IP is needed.
#
# # **✅ EBS (Elastic Block Store) in AWS**(Storage)
# EBS is AWS’s block storage used with EC2 instances—just like a hard drive.
#
# 🔹 Key Points:
# You can attach it to an EC2 instance as its root volume or additional storage.
#
# Data on EBS persists even if the instance stops (unlike EC2 instance store).
#
# Supports snapshots (backups), resizing, and encryption.
#
# Comes in different types like gp3, io1, st1, etc., depending on performance needs.

# %% [markdown]
# # **How to Launch EC2 Instance in AWS using IAM User**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🚀 Steps to Launch EC2 Instance**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **🔹 Step 4: Connect to Your Instance**
#
# Wait for Status = running.
#
# Click Connect.

# %% [markdown]
# # **🔐 What is SSH?**
# SSH is a network protocol that allows you to securely connect to a remote computer (like an EC2 instance) over an unsecured network.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
