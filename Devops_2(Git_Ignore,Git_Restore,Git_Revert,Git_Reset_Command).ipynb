# %% [markdown]
# # **Git Ignore**

# %% [markdown]
# # **👉 What is .gitignore in Git?**
# .gitignore is a special file in Git that tells Git which files or folders to ignore (not track or upload to GitHub).
#
# # **🔍 Why Use .gitignore?**
# To skip temporary files, logs, sensitive info, etc.
#
# Keeps your repository clean and safe.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔄 git restore Command**
#
# git restore is used to undo changes in your working directory or staging area.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Example:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔁 git revert Command**
#
# git revert is used to undo a specific commit by creating a new commit that reverses the changes from the original one — without removing history.

# %% [markdown]
# # **Note:**

# %% [markdown]
# **To find the commit hash ID (short version) for the last or previous commits in VS Code terminal, you can use:**

# %% [markdown]
# ```
# git log --oneline
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Example:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔄 git reset Command**
#
# git reset is used to undo commits or unstage files, depending on how you use it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
