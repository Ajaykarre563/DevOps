# %% [markdown]
# # **what is mean by Kubernetes?**

# %% [markdown]
# Kubernetes is an open-source platform used to automate the deployment, scaling, and management of containerized applications (like Docker containers).
#
# ✅ Simple Example:
# If Docker puts your app in a container, Kubernetes is the system that runs and manages many of those containers across a group of servers.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
