# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🚀 What is a Branch in Git?**
#
# A branch in Git is like a separate line of development.
# It lets you work on new features, fixes, or experiments without affecting the main project.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **if the branch is not available it will create first and switch next**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Git Amend:**

# %% [markdown]
# **It is used to change the message or content of your last commit.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# git commit --amend -m "Login System Done by Me"
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Git Clone**

# %% [markdown]
# # **🔹 What is git clone?**
# git clone means copying a remote Git repository (like from GitHub) to your local computer so you can work on it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **git pull and git fetch:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
