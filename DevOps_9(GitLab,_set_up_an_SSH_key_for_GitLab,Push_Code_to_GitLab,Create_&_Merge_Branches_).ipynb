# %% [markdown]
# # **what is mean by GitLab?**

# %% [markdown]
# **GitLab is a web-based DevOps platform that provides a Git repository manager**
#
# # **with features like:**
#
# # **🔧 Core Features:**
#
# **Version Control:** Uses Git to manage code changes (like GitHub).
#
# **CI/CD Pipelines:** Automates testing, building, and deploying code.
#
# **Issue Tracking:** Track bugs, tasks, and project progress.
#
# **Merge Requests:** Code review and collaboration like GitHub pull requests.
#
# **Self-hosted Option:** Can be installed on your own server (unlike GitHub.com which is cloud-only).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **set up an SSH key for GitLab**

# %% [markdown]
# **1.create a gitlab folder**
#
# **2.use git bash**
#
# **3.run these command**
#
#
#
# ```
# ![image.png](data:image/png;base64,...)
# ```
# 4.go to gitlab folder select public key openwith notepad and then copy it
#
# 5.🔗  Add the SSH Key to GitLab
#
#
# Go to https://gitlab.com and log in.
#
# Click on your profile picture → Edit profile.
#
# In the left sidebar, go to SSH Keys.
#
# Paste your key into the "Key" field.
#
# Add a Title (like “My Laptop Key”).
#
# Click Add key.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Push Code to GitLab**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Create & Merge Branches**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
